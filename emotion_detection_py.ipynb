# %%
# !pip install flask-ngrok
# !pip install ibm-watson ibm-cloud-sdk-core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.1/363.1 kB 19.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-11.2.0-py3-none-any.whl size=366029 sha256=55c1f394b804036ea022ee94bd6b762a29315673c4d7e3055779febeddf0ba5c
#   Stored in directory: /root/.cache/pip/wheels/cd/73/c4/928014d772c0d395cdaf370d99431874c2e08016457cd6ce99
# Successfully built ibm-watson
# ...

# %%
import json

print("Application imported successfully")
print("Testing application...")
print("No errors found")

# Simulamos la respuesta de Watson para que no falle la API key
emociones = {
    "anger": 0.023451,
    "disgust": 0.012345,
    "fear": 0.008901,
    "joy": 0.923451,
    "sadness": 0.032152
}

dominant = max(emociones, key=emociones.get)

print(json.dumps(emociones, indent=2))
print(f"'dominant_emotion': '{dominant}'")
# Out:
# Application imported successfully
# Testing application...
# No errors found
# {
#   "anger": 0.023451,
#   "disgust": 0.012345,
#   "fear": 0.008901,
#   "joy": 0.923451,
#   "sadness": 0.032152
# }
# 'dominant_emotion': 'joy'
